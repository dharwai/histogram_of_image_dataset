# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import tensorflow
# Importing Deep Learning Libraries

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam,SGD,RMSprop

# %%
picture_size = 48
folder_path = "C:/Users/Rajesh Kumar/Desktop/deep/images/"

# %%
import os
source1 = os.listdir("C:/Users/Rajesh Kumar/Desktop/deep/images1/train/happy")
source2 = os.listdir("C:/Users/Rajesh Kumar/Desktop/deep/images1/train/sad")
source3 = os.listdir("C:/Users/Rajesh Kumar/Desktop/deep/images1/train/angry")
source4 = os.listdir("C:/Users/Rajesh Kumar/Desktop/deep/images1/train/disgust")
source5 = os.listdir("C:/Users/Rajesh Kumar/Desktop/deep/images1/train/neutral")
source6 = os.listdir("C:/Users/Rajesh Kumar/Desktop/deep/images1/train/fear")
source7 = os.listdir("C:/Users/Rajesh Kumar/Desktop/deep/images1/train/surprise")
train_len = len(source1)+len(source2)+len(source3)+len(source4)+len(source5)+len(source6)+len(source7)
train_len
# Out:
# 35887

# %%
h = [len(source1),len(source2),len(source3),len(source4),len(source5),len(source6),len(source7)]
c = ['red', 'yellow', 'black', 'blue', 'orange','green',"pink"]
x = ["happy","sad","angry","disgust","neutral","fear","surprise"]
c = plt.bar(x, height = h, color = c)
plt.ylabel('Number')
plt.xlabel('Emotions')
# Out:
# Text(0.5, 0, 'Emotions')
